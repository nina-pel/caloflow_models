# %%
import numpy as np  
import h5py
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score
from nflows.flows.base import Flow
from nflows.distributions.normal import StandardNormal
from nflows.transforms.base import CompositeTransform
from nflows.transforms.coupling import PiecewiseRationalQuadraticCouplingTransform 
from nflows.transforms.permutations import ReversePermutation
from nflows.transforms.coupling import AffineCouplingTransform
import time
import torch.nn as nn
import torch.optim as optim
import os

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

ALPHA = 1e-6

def logit(x):
    return torch.log(x / (1.0 - x))

def logit_trafo(x):
    local_x = torch.clamp(ALPHA + (1. - 2. * ALPHA) * x, min=1e-6, max=1 - 1e-6)
    return logit(local_x)

def inverse_logit(x):
    return (torch.sigmoid(x) - ALPHA) / (1. - 2.*ALPHA)

# Load and preprocess data
path_to_data = '/groups/hephy/mlearning/CaloRegression/training/'
my_file = h5py.File(path_to_data + 'train_piplus.hdf5', 'r')
energy = my_file['energy'][:]
layers = [my_file[f'layer_{i}'][:] for i in range(6)]
E_layers = np.array([layer.sum(axis=(1, 2)) for layer in layers]).T

data = np.hstack((energy.reshape(-1, 1), E_layers))
data[np.isinf(data)] = np.nan
valid_mask = ~np.isnan(data).any(axis=1)
data = data[valid_mask]

data_tensor = torch.tensor(data, dtype=torch.float32).to(device)

data_max = data_tensor.max(dim=0).values
data_tensor = data_tensor / data_max
data_tensor = logit_trafo(data_tensor)

mask = ~torch.isnan(data_tensor).any(dim=1) & ~torch.isinf(data_tensor).any(dim=1)
data_tensor = data_tensor[mask]

data_mean = data_tensor.mean(dim=0)
data_std = data_tensor.std(dim=0)
data_tensor = (data_tensor - data_mean) / data_std

data_mean_reg = data_mean
data_std_reg = data_std
data_max_reg = data_max


context_feature = data_tensor[:, 0].unsqueeze(1)
input_features = data_tensor[:, 1:]

# Define the Flow model
num_layers = 20  
num_features = input_features.shape[1]
base_distribution = StandardNormal(shape=[num_features])

transforms = []

# Create alternating masks for coupling layers
#old version:
#masks = [torch.arange(num_features) % 2 for _ in range(num_layers)]
#masks = [mask if i%2==0 else 1-mask for i,mask in enumerate(masks)]

masks = [(torch.arange(num_features) % 2).bool() for _ in range(num_layers)]
masks = [mask if i % 2 == 0 else ~mask for i, mask in enumerate(masks)]

masks = []
for i in range(num_layers):
    if i % 2 == 0:
        masks.append(torch.tensor(np.random.choice([0,0,0,1,1,1], replace=False,size=6)))
    else:
        masks.append(1-masks[-1])

print(masks)

# Define a custom MLP for the transformation network
class CouplingMLP(nn.Module):
    def __init__(self, in_features, out_features, context_features=1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_features + context_features, 128), nn.LeakyReLU(0.01),
            nn.Linear(128, 128), nn.LeakyReLU(0.01),
            nn.Linear(128, out_features)
        )

    def forward(self, identity_split, context):
        inputs = torch.cat([identity_split, context], dim=-1)
        return self.net(inputs)


# Modify Flow model to use the custom MLP
for i in range(num_layers):
   # transforms.append(ReversePermutation(features=num_features))
    transforms.append(AffineCouplingTransform(
        mask=masks[i],
        transform_net_create_fn=lambda in_features, out_features: CouplingMLP(in_features, out_features, context_features=1)
    ))

transform = CompositeTransform(transforms)
flow = Flow(transform, base_distribution).to(device)

def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)

flow.apply(init_weights)


# Training the Flow
#changed: old version
#optimizer = torch.optim.Adam(flow.parameters(), lr=1e-4)
optimizer = torch.optim.Adam(flow.parameters(), lr=1e-3)
num_epochs = 100
batch_size = 256
best_loss = float('inf')

for epoch in range(num_epochs):
    idx = torch.randperm(len(data_tensor))
    data_tensor = data_tensor[idx]
    context_feature = data_tensor[:, 0].unsqueeze(1)
    input_features = data_tensor[:, 1:]

    for i in range(0, len(input_features), batch_size):
        batch_inputs = input_features[i:i + batch_size]
        batch_context = context_feature[i:i + batch_size]
        optimizer.zero_grad()
        loss = -flow.log_prob(inputs=batch_inputs, context=batch_context).mean()
        if not torch.isnan(loss) and not torch.isinf(loss):
            loss.backward()
            optimizer.step()
            best_loss = min(best_loss, loss.item())
        else:
            print("skipping")
        #print(f"batch {i}, Loss: {loss.item()}")
    
    if (epoch + 1) % 50 == 0:
        print(f"Epoch {epoch + 1}, Loss: {loss.item()}")
        
print(f"final best loss: {best_loss}")
# Generate Samples
n_samples = 200000
batch_size = 1000
all_samples = []

Einc_gen = torch.rand((n_samples, 1)).to(device) * 99 + 1
Einc_gen = Einc_gen / data_max[0]
Einc_gen = logit_trafo(Einc_gen)
Einc_gen = (Einc_gen - data_mean[0]) / data_std[0]

with torch.no_grad():
    for i in range(0, n_samples, batch_size):
        batch_context = Einc_gen[i:i + batch_size]
        samples_batch = flow.sample(1, context=batch_context).detach().cpu()
        all_samples.append(samples_batch)

samples = torch.cat(all_samples, dim=0)
samples = samples * data_std[1:].cpu() + data_mean[1:].cpu()
samples = inverse_logit(samples)
samples = samples * data_max[1:].cpu()
samples = samples.squeeze().numpy()

# Plot Histograms
fig, axs = plt.subplots(2, 3, figsize=(18, 12))  # Adjust width and heigh

axs = axs.flatten()
colors = ['yellow', 'green', 'red', 'purple', 'orange', 'cyan']

for i in range(data.shape[1] - 1):
    bins = np.logspace(0, 5, 100)
    counts, bin_edges, _ = axs[i].hist(
        data[:, i + 1], bins=bins, alpha=0.5, label="Reference Data", color=colors[i % len(colors)], density=True, log=True
    )
    axs[i].hist(samples[:, i], bins=bin_edges, alpha=0.5, label="Generated Data", color='blue', density=True, log=True)
    axs[i].set_xscale('log')
    axs[i].legend()
    axs[i].set_title(f"Feature {i + 1}")

for j in range(len(axs)):
    if j >= data.shape[1] - 1:
        axs[j].axis('off')

plt.tight_layout()
fig_outdir = "regression_figures"
os.makedirs(fig_outdir, exist_ok=True)
outpath = os.path.join(fig_outdir, "CLNF_layer_energy_histograms.png")
plt.savefig(outpath, dpi=600, bbox_inches="tight")
print(f"Saved: {outpath}")
plt.show()
# Out:
# Using device: cuda
# [tensor([0, 1, 0, 1, 0, 1]), tensor([1, 0, 1, 0, 1, 0]), tensor([1, 1, 0, 0, 0, 1]), tensor([0, 0, 1, 1, 1, 0]), tensor([0, 1, 0, 0, 1, 1]), tensor([1, 0, 1, 1, 0, 0]), tensor([0, 1, 0, 1, 1, 0]), tensor([1, 0, 1, 0, 0, 1]), tensor([1, 0, 0, 1, 0, 1]), tensor([0, 1, 1, 0, 1, 0]), tensor([1, 1, 0, 1, 0, 0]), tensor([0, 0, 1, 0, 1, 1]), tensor([1, 0, 1, 0, 0, 1]), tensor([0, 1, 0, 1, 1, 0]), tensor([1, 0, 1, 0, 1, 0]), tensor([0, 1, 0, 1, 0, 1]), tensor([0, 1, 0, 1, 1, 0]), tensor([1, 0, 1, 0, 0, 1]), tensor([0, 0, 1, 0, 1, 1]), tensor([1, 1, 0, 1, 0, 0])]
# Epoch 50, Loss: 5.595575332641602
# Epoch 100, Loss: 5.563412666320801
# final best loss: 5.54338264465332
# Saved: regression_figures/CLNF_layer_energy_histograms.png

# %%
#CLASSIFIER
from sklearn.calibration import calibration_curve
from sklearn.isotonic import IsotonicRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import copy

ALPHA = 1e-6

import numpy as np

def logit(x):
    return np.log(x / (1.0 - x))

def logit_trafo(x):
    local_x = np.clip(ALPHA + (1. - 2. * ALPHA) * x, 1e-6, 1 - 1e-6)
    return logit(local_x)


real_data = data_tensor.cpu().numpy()
Einc_gen_numpy = Einc_gen.cpu().numpy().reshape(-1, 1) 
samples_with_einc = np.hstack((Einc_gen_numpy, samples))  
generated_data = samples_with_einc

print(type(real_data))
print(type(generated_data))

# Compute max, mean, std based on **combined** dataset
combined = np.vstack((real_data, generated_data))

data_max = combined.max(axis=0)
data_mean = combined.mean(axis=0)
data_std = combined.std(axis=0)

# Apply same transformations to both datasets
real_data = real_data / data_max
generated_data = generated_data / data_max

real_data = logit_trafo(real_data)
generated_data = logit_trafo(generated_data)

real_data = (real_data - data_mean) / data_std
generated_data = (generated_data - data_mean) / data_std

#added here because auc was wrong
# Drop the first column (Einc) before using for classification
real_data = real_data[:, 1:]
generated_data = generated_data[:, 1:]

#changes end here

# Create labels
smallest_size = min(len(real_data), len(generated_data))

# Randomly select smallest_size indices
real_indices = np.random.choice(len(real_data), smallest_size, replace=False)
generated_indices = np.random.choice(len(generated_data), smallest_size, replace=False)

# Select only those samples
real_data = real_data[real_indices]
generated_data = generated_data[generated_indices]

print(f"Final real data shape: {real_data.shape}")
print(f"Final gen shape: {generated_data.shape}")

real_labels = np.ones(len(real_data))  
maf_labels = np.zeros(len(generated_data))

# combining of real and KDE gen data
#combined_data = np.vstack((real_data[:, 1:], generated_data))
combined_data = np.vstack((real_data, generated_data))
combined_labels = np.hstack((real_labels, maf_labels))

# split into trainning and test sets
X_train, X_test, y_train, y_test = train_test_split(combined_data, combined_labels, test_size=0.2, random_state=42)

#CLASSIFIER SETUP
class SimpleNN(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 1)
        self.dropout = nn.Dropout(0.3)
        
    def forward(self, x):
        x = F.leaky_relu(self.fc1(x), negative_slope=0.01)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), negative_slope=0.01)
        x = self.dropout(x)
        x = torch.sigmoid(self.fc3(x))
        return x

def train_model(model, criterion, optimizer, dataloaders, num_epochs=25):
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    
    for epoch in range(num_epochs):
        print('Epoch number {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device).float().unsqueeze(1)
                
                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    preds = torch.round(outputs)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.9f} Acc: {:.9f}'.format(
                phase, epoch_loss, epoch_acc))

            if phase == 'val' and epoch_acc  > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = copy.deepcopy(model.state_dict())

    print('highest validation accuracy: {:9f}'.format(best_acc))
    model.load_state_dict(best_model_wts)
    return model

def evaluate_model(model, dataloaders):
    model.eval()
    all_preds = []
    all_labels = []
    all_preds_auc = []

    for inputs, labels in dataloaders['val']:
        inputs = inputs.to(device)
        labels = labels.to(device).float().unsqueeze(1)
        
        with torch.no_grad():
            outputs = model(inputs)
            preds = torch.round(outputs)
            preds_auc = outputs
            all_preds_auc.append(preds_auc.cpu().numpy())
            all_preds.append(preds.cpu().numpy())
            all_labels.append(labels.cpu().numpy())
    
    all_preds_auc = np.concatenate(all_preds_auc)
    all_preds = np.concatenate(all_preds)
    all_labels = np.concatenate(all_labels)
    acc = accuracy_score(all_labels, all_preds)
    auc = roc_auc_score(all_labels, all_preds_auc)
    print('Accuracy: {:.9f}, AUC (area under roc curve): {:.9f}'.format(acc, auc))
    return acc, auc

# dataloader setup
train_dataset = torch.utils.data.TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
test_dataset = torch.utils.data.TensorDataset(torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test, dtype=torch.float32))

dataloaders = {
    'train': torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True),
    'val': torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=True)
}

# Model, criterion, optimizer
input_dim = combined_data.shape[1]
hidden_dim = 64
model = SimpleNN(input_dim, hidden_dim)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# train & evaluate
model = train_model(model, criterion, optimizer, dataloaders, num_epochs=25)
evaluate_model(model, dataloaders)


#end_time = time.time()

#elapsed_time = end_time - start_time
#hours, rem = divmod(elapsed_time, 3600)
#minutes, seconds = divmod(rem, 60)
#print(f"Total time taken: {int(hours)}h {int(minutes)}m {seconds:.2f}s")
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Final real data shape: (70000, 6)
# Final gen shape: (70000, 6)
# Epoch number 0/24
# ----------
# train Loss: 0.693427888 Acc: 0.500758929
# val Loss: 0.693309095 Acc: 0.496607143
# Epoch number 1/24
# ----------
# train Loss: 0.693222491 Acc: 0.500651786
# val Loss: 0.693614079 Acc: 0.496607143
# Epoch number 2/24
# ----------
# train Loss: 0.693242495 Acc: 0.497419643
# val Loss: 0.693215434 Acc: 0.496607143
# Epoch number 3/24
# ----------
# train Loss: 0.693229781 Acc: 0.499919643
# val Loss: 0.693123130 Acc: 0.503392857
# Epoch number 4/24
# ----------
# train Loss: 0.693207284 Acc: 0.501285714
# val Loss: 0.693422077 Acc: 0.496607143
# Epoch number 5/24
# ----------
# train Loss: 0.693189536 Acc: 0.501321429
# val Loss: 0.693191509 Acc: 0.496607143
# Epoch number 6/24
# ----------
# train Loss: 0.693210062 Acc: 0.497821429
# val Loss: 0.693139433 Acc: 0.496607143
# Epoch number 7/24
# ----------
# train Loss: 0.693200524 Acc: 0.500955357
# val Loss: 0.693181108 Acc: 0.496607143
# Epoch number 8/24
# ----------
# train Loss: 0.693187046 Acc: 0.498776786
# val Loss: 0.693232185 Acc: 0.496607143
# Epoch number 9/24
# ----------
# train Loss: 0.693196174 Acc: 0.501098214
# val Loss: 0.693157734 Acc: 0.496607143
# Epoch number 10/24
# ----------
# train Loss: 0.693175068 Acc: 0.501767857
# val Loss: 0.693106062 Acc: 0.503392857
# Epoch number 11/24
# ----------
# train Loss: 0.693172885 Acc: 0.502357143
# val Loss: 0.693295917 Acc: 0.496607143
# Epoch number 12/24
# ----------
# train Loss: 0.693177804 Acc: 0.502633929
# val Loss: 0.693041839 Acc: 0.503392857
# Epoch number 13/24
# ----------
# train Loss: 0.693145860 Acc: 0.504803571
# val Loss: 0.693087646 Acc: 0.496607143
# Epoch number 14/24
# ----------
# train Loss: 0.693204386 Acc: 0.501383929
# val Loss: 0.693086995 Acc: 0.503392857
# Epoch number 15/24
# ----------
# train Loss: 0.693153268 Acc: 0.502098214
# val Loss: 0.693133780 Acc: 0.496607143
# Epoch number 16/24
# ----------
# train Loss: 0.693218113 Acc: 0.499464286
# val Loss: 0.693131987 Acc: 0.496607143
# Epoch number 17/24
# ----------
# train Loss: 0.693155644 Acc: 0.502767857
# val Loss: 0.693568863 Acc: 0.503392857
# Epoch number 18/24
# ----------
# train Loss: 0.693159593 Acc: 0.501267857
# val Loss: 0.693017295 Acc: 0.503392857
# Epoch number 19/24
# ----------
# train Loss: 0.693131319 Acc: 0.503241071
# val Loss: 0.693074819 Acc: 0.503392857
# Epoch number 20/24
# ----------
# train Loss: 0.692992208 Acc: 0.508089286
# val Loss: 0.692579166 Acc: 0.503392857
# Epoch number 21/24
# ----------
# train Loss: 0.692921245 Acc: 0.507767857
# val Loss: 0.692666684 Acc: 0.496607143
# Epoch number 22/24
# ----------
# train Loss: 0.693046440 Acc: 0.507017857
# val Loss: 0.693303186 Acc: 0.496607143
# Epoch number 23/24
# ----------
# train Loss: 0.693157584 Acc: 0.504142857
# val Loss: 0.693064437 Acc: 0.496607143
# Epoch number 24/24
# ----------
# train Loss: 0.693105783 Acc: 0.506758929
# val Loss: 0.692982555 Acc: 0.496607143
# highest validation accuracy:  0.503393
# Accuracy: 0.503392857, AUC (area under roc curve): 0.958418098
# (0.5033928571428572, 0.9584180980782405)

# %%
import os
import time

energy_values = list(range(10, 91, 10)) 
eval_folder = '/groups/hephy/mlearning/CaloRegression/evaluation'
errors_by_energy = {}
print(data_max_reg[0])

# =========================
# FIGURE OUTPUT SETTINGS  (NEU)
# =========================
fig_outdir = "figures_regression"
os.makedirs(fig_outdir, exist_ok=True)

SAVE_DPI = 400
SAVE_FORMAT = "pdf"

t0_total = time.time()  # TOTAL RUNTIME TIMER START

def logit_reg(x):
    return torch.log(x / (1.0 - x))

def logit_trafo_reg(x):
    local_x = torch.clamp(ALPHA + (1. - 2. * ALPHA) * x, min=1e-6, max=1 - 1e-6)
    return logit_reg(local_x)

def inverse_logit_reg(x):
    return (torch.sigmoid(x) - ALPHA) / (1. - 2.*ALPHA)

#LOAD AND PREPROCESS TEST DATA
def load_and_preprocess_test_file(filepath, data_mean_reg, data_std_reg, data_max_reg):
    with h5py.File(filepath, 'r') as f:
        energy = f['energy'][:]
        layers = [f[f'layer_{i}'][:] for i in range(6)]
        E_layers = np.array([layer.sum(axis=(1, 2)) for layer in layers]).T

    data = np.hstack((energy.reshape(-1, 1), E_layers))
    data[np.isinf(data)] = np.nan
    valid_mask = ~np.isnan(data).any(axis=1)
    data = data[valid_mask]

    tensor_data = torch.tensor(data, dtype=torch.float32).to(device)
    #preprocessing
    tensor_data = tensor_data / data_max_reg  
    tensor_data = logit_trafo_reg(tensor_data)  
    tensor_data = (tensor_data - data_mean_reg) / data_std_reg 

    return tensor_data[:, 1:]  #return only layers (context is inferred)

#ENERGY INFERENCE
def infer_incident_energy(flow, layer_tensor, data_mean_reg, data_std_reg, data_max_reg, num_scan_points=1000):
    device = layer_tensor.device
    n_samples = layer_tensor.shape[0]
    E_candidates = torch.linspace(1, 180, num_scan_points, device=device).view(-1, 1)

    E_candidates_norm = E_candidates / data_max_reg[0]
    E_candidates_logit = logit_trafo_reg(E_candidates_norm)
    E_candidates_std = (E_candidates_logit - data_mean_reg[0]) / data_std_reg[0]

    #prep context
    E_context = E_candidates_std.view(1, -1, 1).repeat(n_samples, 1, 1)
    inputs = layer_tensor.unsqueeze(1).repeat(1, num_scan_points, 1)

    flat_inputs = inputs.view(-1, inputs.shape[-1])
    flat_context = E_context.view(-1, 1)

    batch_size = 1000  
    log_probs_list = []
    with torch.no_grad():
        for i in range(0, flat_inputs.shape[0], batch_size):
            inputs_batch = flat_inputs[i:i + batch_size]
            context_batch = flat_context[i:i + batch_size]
            log_probs_batch = flow.log_prob(inputs_batch, context=context_batch)
            log_probs_list.append(log_probs_batch)

    log_probs = torch.cat(log_probs_list).view(n_samples, num_scan_points)
    max_indices = log_probs.argmax(dim=1)
    inferred_E = E_candidates[max_indices].cpu().numpy()

    return inferred_E

#training values
data_mean_reg = data_mean_reg.to(device)
data_std_reg = data_std_reg.to(device)    
data_max_reg = data_max_reg.to(device)   
flow = flow.to(device)   

errors_by_energy = {}

for E_true in energy_values:
    file_path = os.path.join(eval_folder, f'piplus_{E_true}GeV.hdf5')

    layer_tensor = load_and_preprocess_test_file(
        file_path, data_mean_reg, data_std_reg, data_max_reg
    )
    inferred = infer_incident_energy(
        flow, layer_tensor, data_mean_reg, data_std_reg, data_max_reg
    )

    error = inferred - E_true
    errors_by_energy[E_true] = error

    print(f"E_inc={E_true} GeV: mean error = {np.mean(error):.2f}, std = {np.std(error):.2f}")

    bins = 100
    counts, bin_edges = np.histogram(inferred, bins=bins, range=(1, 180))

    bin_idx = np.digitize(E_true, bin_edges) - 1
    bin_idx = np.clip(bin_idx, 0, len(counts) - 1)

    true_bin_count = counts[bin_idx]
    ratio_true_bin = true_bin_count / counts.sum() if counts.sum() > 0 else 0
    print(f"  Bin count of true energy ({E_true} GeV): {true_bin_count} ({ratio_true_bin:.2%})")

    max_count = counts.max()
    half_max = max_count / 2
    above_half_max = np.where(counts >= half_max)[0]
    if len(above_half_max) > 0:
        fwhm = bin_edges[above_half_max[-1] + 1] - bin_edges[above_half_max[0]]
    else:
        fwhm = 0.0

    print(f"  Full width at half maximum (FWHM): {fwhm:.2f} GeV")

# =========================
# PLOT 1: INFERRED ENERGIES
# =========================
plt.figure(figsize=(12, 6))

for i, (E_true, error) in enumerate(errors_by_energy.items()):
    inferred = error + E_true
    plt.hist(inferred, bins=100, range=(0, 120), alpha=0.5, label=f'True {E_true} GeV')

    if i == 0:
        plt.axvline(E_true, color='black', linestyle='--', label='True $E_{inc}$ value')
    else:
        plt.axvline(E_true, color='black', linestyle='--')

plt.xlabel("Inferred incident energy (GeV)")
plt.ylabel("Counts")
plt.title("Inferred energy distributions by true $E_{inc}$")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig(
    os.path.join(fig_outdir, "AffineCLNF_inferred_energy_distributions.pdf"),
    dpi=SAVE_DPI,
    bbox_inches="tight"
)
plt.show()

# =========================
# PLOT 2: ERROR DISTRIBUTIONS
# =========================
plt.figure(figsize=(12, 6))
for E_true, error in errors_by_energy.items():
    plt.hist(error, bins=50, alpha=0.5, label=f'{E_true} GeV')

plt.axvline(0, color='black', linestyle='--')
plt.xlabel("E_found - E_inc (GeV)")
plt.ylabel("Counts")
plt.title("Error distribution for different true energies")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig(
    os.path.join(fig_outdir, "AffineCLNF_error_distributions_by_energy.pdf"),
    dpi=SAVE_DPI,
    bbox_inches="tight"
)
plt.show()

t_total = time.time() - t0_total
print(f"\nTotal runtime: {t_total:.2f} s ({t_total/60:.2f} min)")
# Out:
# tensor(99.9993, device='cuda:0')
# E_inc=10 GeV: mean error = 0.59, std = 2.33
#   Bin count of true energy (10 GeV): 35379 (35.38%)
#   Full width at half maximum (FWHM): 3.58 GeV
# E_inc=20 GeV: mean error = 0.83, std = 3.40
#   Bin count of true energy (20 GeV): 25898 (25.90%)
#   Full width at half maximum (FWHM): 5.37 GeV
# E_inc=30 GeV: mean error = 1.07, std = 4.26
#   Bin count of true energy (30 GeV): 20431 (20.43%)
#   Full width at half maximum (FWHM): 8.95 GeV
# E_inc=40 GeV: mean error = 1.31, std = 4.95
#   Bin count of true energy (40 GeV): 16970 (16.97%)
#   Full width at half maximum (FWHM): 8.95 GeV
# E_inc=50 GeV: mean error = 1.40, std = 5.50
#   Bin count of true energy (50 GeV): 15352 (15.35%)
#   Full width at half maximum (FWHM): 10.74 GeV
# E_inc=60 GeV: mean error = 1.26, std = 5.86
#   Bin count of true energy (60 GeV): 14014 (14.01%)
#   Full width at half maximum (FWHM): 10.74 GeV
# E_inc=70 GeV: mean error = 0.81, std = 6.39
#   Bin count of true energy (70 GeV): 12908 (12.91%)
#   Full width at half maximum (FWHM): 12.53 GeV
# E_inc=80 GeV: mean error = 0.34, std = 6.69
#   Bin count of true energy (80 GeV): 11790 (11.79%)
#   Full width at half maximum (FWHM): 14.32 GeV
# E_inc=90 GeV: mean error = -0.88, std = 6.13
#   Bin count of true energy (90 GeV): 11162 (11.16%)
#   Full width at half maximum (FWHM): 16.11 GeV
# Total runtime: 7196.51 s (119.94 min)

# %%
test_file_path = '/groups/hephy/mlearning/CaloRegression/evaluation/piplus_20GeV.hdf5'


def logit_reg(x):
    return torch.log(x / (1.0 - x))

def logit_trafo_reg(x):
    local_x = torch.clamp(ALPHA + (1. - 2. * ALPHA) * x, min=1e-6, max=1 - 1e-6)
    return logit_reg(local_x)

def inverse_logit_reg(x):
    return (torch.sigmoid(x) - ALPHA) / (1. - 2.*ALPHA)

# LOAD AND PREPROCESS TEST DATA ===
def load_and_preprocess_test_file(filepath, data_mean, data_std, data_max):
    with h5py.File(filepath, 'r') as f:
        energy = f['energy'][:]
        layers = [f[f'layer_{i}'][:] for i in range(6)]
        E_layers = np.array([layer.sum(axis=(1, 2)) for layer in layers]).T

    data = np.hstack((energy.reshape(-1, 1), E_layers))
    data[np.isinf(data)] = np.nan
    valid_mask = ~np.isnan(data).any(axis=1)
    data = data[valid_mask]

    tensor_data = torch.tensor(data, dtype=torch.float32).to(device)
    #preprocessing-- brauchts das nochmal??
    tensor_data = tensor_data / data_max  # normalize by max
    tensor_data = logit_trafo_reg(tensor_data)  # logit transform
    #tensor_data = (tensor_data - data_mean) / data_std  # standardize

    return tensor_data[:, 1:]  # return only layers (context is inferred)

# === ENERGY INFERENCE ===
def infer_incident_energy(flow, layer_tensor, data_mean, data_std, data_max, num_scan_points=1000):
    device = layer_tensor.device
    n_samples = layer_tensor.shape[0]

    # === Candidate energies (in GeV) ===
    E_candidates = torch.linspace(1, 100, num_scan_points, device=device).view(-1, 1)

    # === Correct preprocessing (1D) ===
    # Only use the scalar preprocessing for the incident energy (index 0)
    """
    E_candidates_norm = E_candidates / data_max[0]
    E_candidates_logit = logit_trafo_reg(E_candidates_norm)
    E_candidates_std = (E_candidates_logit - data_mean[0]) / data_std[0]
    """
    E_candidates_norm = E_candidates / data_max
    E_candidates_logit = logit_trafo_reg(E_candidates_norm)
    E_candidates_std = (E_candidates_logit - data_mean) / data_std

    # === Prepare context (broadcast to match number of samples) ===
    E_context = E_candidates_std.view(1, -1, 1).repeat(n_samples, 1, 1)  # shape [n_samples, num_scan_points, 1]
    inputs = layer_tensor.unsqueeze(1).repeat(1, num_scan_points, 1)     # shape [n_samples, num_scan_points, features]

    # === Flatten inputs and context ===
    flat_inputs = inputs.view(-1, inputs.shape[-1])      # [n_samples * num_scan_points, features]
    flat_context = E_context.view(-1, 1)                 # [n_samples * num_scan_points, 1]
    print("\n=== Debug Info ===")
    print("data_max[0]:", data_max[0].item())
    print("data_mean[0]:", data_mean[0].item())
    print("data_std[0]:", data_std[0].item())
    print("E_candidates[:5]:", E_candidates[:5].view(-1).cpu().numpy())
    print("E_candidates_norm[:5]:", E_candidates_norm[:5].view(-1).cpu().numpy())
    print("E_candidates_logit[:5]:", E_candidates_logit[:5].view(-1).cpu().numpy())
    print("E_candidates_std[:5]:", E_candidates_std[:5].view(-1).cpu().numpy())
    # === Batched log_prob evaluation ===
    batch_size = 10000  # Adjust based on available GPU memory
    log_probs_list = []
    with torch.no_grad():
        for i in range(0, flat_inputs.shape[0], batch_size):
            inputs_batch = flat_inputs[i:i + batch_size]
            context_batch = flat_context[i:i + batch_size]
            log_probs_batch = flow.log_prob(inputs_batch, context=context_batch)
            log_probs_list.append(log_probs_batch)

    # === Combine and reshape ===
    log_probs = torch.cat(log_probs_list).view(n_samples, num_scan_points)
    print("\n=== Log Prob Diagnostics ===")
    print("log_probs[0][:10]:", log_probs[0][:10].cpu().numpy())
    print("log_probs[0].max():", log_probs[0].max().item())
    print("log_probs[0].min():", log_probs[0].min().item())
    print("log_probs[0].std():", log_probs[0].std().item())

    # === Select max log_prob index for each sample ===
    max_indices = log_probs.argmax(dim=1)
    inferred_E = E_candidates[max_indices].cpu().numpy()

    return inferred_E


# from the training script
data_mean = torch.tensor(data_mean, dtype=torch.float32, device=device)
data_std = torch.tensor(data_std, dtype=torch.float32, device=device)
data_max = torch.tensor(data_max, dtype=torch.float32, device=device)

data_mean = data_mean.to(device)  # shape [7]
data_std = data_std.to(device)    # shape [7]
data_max = data_max.to(device)    # shape [7]
flow =flow.to(device)          # your trained conditional flow model

# === RUN EVALUATION ===
test_layers_tensor = load_and_preprocess_test_file(test_file_path, data_mean, data_std, data_max)
# === Test Input Diagnostics ===
print("=== Test Input Diagnostics ===")
print("test_layers_tensor[:5]:", test_layers_tensor[:5].cpu())
print("test_layers_tensor.std():", test_layers_tensor.std().item())

inferred_energies = infer_incident_energy(flow, test_layers_tensor, data_mean, data_std, data_max)
#print(inferred_energies.shape)
random_indices = torch.randperm(len(inferred_energies))[:20]
print(inferred_energies[random_indices])

# === PLOT RESULTS ===
plt.figure(figsize=(10, 6))
plt.hist(inferred_energies, bins=100, alpha=0.7, color='skyblue', label="Inferred $E_{inc}$")
plt.axvline(20, color='black', linestyle='--', label='True 20 GeV')
plt.xlabel("Inferred Incident Energy (GeV)")
plt.ylabel("Counts")
plt.legend()
plt.title("Regressive Evaluation of Flow Model (E_inc = 20 GeV)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Test Input Diagnostics ===
# test_layers_tensor[:5]: tensor([[ -5.8704,  -5.8208,  -6.8126,  -2.0483,  -3.2249, -13.8155],
#         [ -5.5347,  -5.0265,  -6.5492,  -2.7033,  -2.7727,  -9.8764],
#         [ -6.0330,  -5.3933,  -5.9181,  -1.5567, -12.3420, -13.8155],
#         [ -6.0059,  -5.7271,  -2.6173,  -2.0687,  -5.4557, -13.8155],
#         [ -2.8527,  -1.8500,  -3.9339,  -3.8338, -13.8155, -13.8155]])
# test_layers_tensor.std(): 4.007924556732178
#
# === Debug Info ===
# data_max[0]: 7.950750350952148
# data_mean[0]: -0.0041710021905601025
# data_std[0]: 1.0026298761367798
# E_candidates[:5]: [1.        1.0990992 1.1981982 1.2972972 1.3963964]
# E_candidates_norm[:5]: [1.25774294e-01 4.24832397e-05 1.12347552e-05 3.96195246e-05
#  8.22517632e-06 8.96851907e-06 1.15660532e-05 1.38238415e-01
#  4.66932906e-05 1.23481095e-05 4.35457878e-05 9.04028366e-06
#  9.85729184e-06 1.27122394e-05 1.50702536e-01 5.09033380e-05
#  1.34614629e-05 4.74720437e-05 9.85539100e-06 1.07460637e-05
#  1.38584246e-05 1.63166642e-01 5.51133890e-05 1.45748163e-05
#  5.13982995e-05 1.06704983e-05 1.16348356e-05 1.50046098e-05
#  1.75630763e-01 5.93234399e-05 1.56881706e-05 5.53245627e-05
#  1.14856066e-05 1.25236083e-05 1.61507960e-05]
# E_candidates_logit[:5]: [ -1.9388428 -10.043094  -11.311219  -10.111223  -11.593567  -11.51607
#  -11.284501   -1.8299928  -9.950674  -11.224124  -10.01895   -11.508897
#  -11.430665  -11.19721    -1.729096   -9.866077  -11.144011   -9.934477
#  -11.43084   -11.351982  -11.116931   -1.6348481  -9.788082  -11.069841
#   -9.856586  -11.358437  -11.279042  -11.04262    -1.5462303  -9.715732
#  -11.000795   -9.784326  -11.290923  -11.211062  -10.973451 ]
# E_candidates_std[:5]: [-1.9295971  -0.54362535 -0.59986776 -0.3254485  -0.5707498  -0.5600706
#  -0.28529307 -1.8210326  -0.5436111  -0.59986293 -0.32541963 -0.57074606
#  -0.56006753 -0.28528732 -1.7204006  -0.54359806 -0.59985846 -0.3253932
#  -0.5707426  -0.5600647  -0.285282   -1.6263999  -0.5435861  -0.5998544
#  -0.32536882 -0.5707394  -0.56006205 -0.2852771  -1.5380145  -0.543575
#  -0.5998506  -0.3253462  -0.57073635 -0.56005955 -0.28527257]
#
# === Log Prob Diagnostics ===
# log_probs[0][:10]: [-21969.938 -21113.424 -21156.426 -20946.568 -21133.771 -21125.693
#  -20915.53  -21912.176 -21113.408 -21156.404]
# log_probs[0].max(): -17618.662109375
# log_probs[0].min(): -21969.9375
# log_probs[0].std(): 792.339111328125
# [[ 1.0990992]
#  [ 1.2972972]
#  [ 1.1981982]
#  [ 1.1981982]
#  [50.25225  ]
#  [ 1.0990992]
#  [ 1.1981982]
#  [ 1.3963964]
#  [50.25225  ]
#  [ 1.3963964]
#  [ 1.3963964]
#  [ 1.3963964]
#  [ 1.1981982]
#  [ 1.0990992]
#  [ 1.3963964]
#  [ 1.4954956]
#  [ 1.2972972]
#  [ 1.0990992]
#  [ 1.1981982]
#  [ 1.5945946]]

# %%
# =========================
# SIMPLE TASK 2: REGRESSION PERFORMANCE SUMMARY
# (per-energy + global, with optional saturation filtering)
# =========================

import numpy as np

def width68(errors):
    """Central 68% interval width: Q84 - Q16."""
    if len(errors) == 0:
        return np.nan
    return np.quantile(errors, 0.84) - np.quantile(errors, 0.16)

def metrics(errors):
    """Return Bias, MAE, RMSE, Std, 68%-width + N for a 1D error array."""
    errors = np.asarray(errors).reshape(-1)
    if errors.size == 0:
        return 0, np.nan, np.nan, np.nan, np.nan, np.nan
    bias = float(np.mean(errors))
    mae  = float(np.mean(np.abs(errors)))
    rmse = float(np.sqrt(np.mean(errors**2)))
    std  = float(np.std(errors))
    w68  = float(width68(errors))
    return int(errors.size), bias, mae, rmse, std, w68

def print_regression_summary(errors_by_energy, sat_by_energy=None, filter_saturated=True):
    """
    errors_by_energy: dict {E_true: error_array} where error = E_pred - E_true
    sat_by_energy:    optional dict {E_true: bool_array} True = saturated (same length as error_array)
                      Recommended definition: argmax at scan edge (first/last candidate).
    filter_saturated: if True, compute metrics on non-saturated only.
                      Sat. frac is always computed on full sample.
    """
    energies = sorted(errors_by_energy.keys())

    # store rows and build pooled arrays
    rows = []
    pooled_errors = []
    pooled_trueE = []

    # header
    tag = "edge-saturation filtered" if filter_saturated else "unfiltered"
    print(f"\n=== Per-energy regression summary ({tag}) ===")
    print(f"{'E_true [GeV]':>10} {'N':>10} {'Bias [GeV]':>11} {'MAE [GeV]':>10} {'RMSE [GeV]':>11} {'Std [GeV]':>10} {'68% width [GeV]':>16} {'Sat. frac':>10}")

    for E in energies:
        err = np.asarray(errors_by_energy[E]).reshape(-1)

        # saturation mask (optional)
        if sat_by_energy is None:
            sat = np.zeros(err.size, dtype=bool)
        else:
            sat = np.asarray(sat_by_energy[E], dtype=bool).reshape(-1)
            if sat.size != err.size:
                raise ValueError(f"sat_by_energy[{E}] has size {sat.size}, expected {err.size}")

        sat_frac = (np.mean(sat) * 100.0) if err.size > 0 else np.nan

        # filter for metrics if requested
        use = err[~sat] if filter_saturated else err

        N, bias, mae, rmse, std, w68 = metrics(use)

        print(f"{int(E):10d} {N:10d} {bias:11.3f} {mae:10.3f} {rmse:11.3f} {std:10.3f} {w68:16.3f} {sat_frac:9.2f}%")

        # pool (same filtering choice)
        pooled_errors.append(use)
        pooled_trueE.append(np.full(use.size, float(E)))

    # global
    pooled_errors = np.concatenate(pooled_errors) if sum(map(len, pooled_errors)) > 0 else np.array([])
    pooled_trueE  = np.concatenate(pooled_trueE)  if sum(map(len, pooled_trueE)) > 0 else np.array([])

    N, bias, mae, rmse, std, w68 = metrics(pooled_errors)

    rel_mae  = float(np.mean(np.abs(pooled_errors) / pooled_trueE) * 100.0) if N > 0 else np.nan
    rel_rmse = float(np.sqrt(np.mean((pooled_errors / pooled_trueE) ** 2)) * 100.0) if N > 0 else np.nan

    print(f"\n=== Global regression summary (all energies pooled) ===")
    print(f"Total N: {N}")
    print(f"Bias  [GeV]: {bias:.3f}")
    print(f"MAE   [GeV]: {mae:.3f}")
    print(f"RMSE  [GeV]: {rmse:.3f}")
    print(f"Std   [GeV]: {std:.3f}")
    print(f"68% width [GeV]: {w68:.3f}")
    print(f"Relative MAE  [%]: {rel_mae:.3f}")
    print(f"Relative RMSE [%]: {rel_rmse:.3f}")


# =========================
# HOW TO CALL IT
# =========================
# You already have:
#   errors_by_energy[E_true] = inferred - E_true
#
# If you ALSO have saturation masks:
#   sat_by_energy[E_true] = boolean array (True = saturated)
# then:
#
# print_regression_summary(errors_by_energy, sat_by_energy=sat_by_energy, filter_saturated=True)
#
# If you do NOT have sat_by_energy yet, you can still run unfiltered:
print_regression_summary(errors_by_energy, sat_by_energy=None, filter_saturated=False)
# Out:
# === Per-energy regression summary (unfiltered) ===
# E_true [GeV]          N  Bias [GeV]  MAE [GeV]  RMSE [GeV]  Std [GeV]  68% width [GeV]  Sat. frac
#         10     100000       0.589      1.663       2.407      2.334            3.584      0.00%
#         20     100000       0.829      2.500       3.495      3.395            5.734      0.00%
#         30     100000       1.068      3.194       4.395      4.263            7.346      0.00%
#         40     100000       1.314      3.740       5.118      4.946            8.601      0.00%
#         50     100000       1.403      4.206       5.678      5.502            9.855      0.00%
#         60     100000       1.260      4.405       5.993      5.860           10.213      0.00%
#         70     100000       0.809      4.834       6.443      6.392           11.647      0.00%
#         80     100000       0.343      5.140       6.696      6.687           12.363      0.00%
#         90     100000      -0.877      4.975       6.196      6.133           12.543      0.00%
#
# === Global regression summary (all energies pooled) ===
# Total N: 900000
# Bias  [GeV]: 0.749
# MAE   [GeV]: 3.851
# RMSE  [GeV]: 5.338
# Std   [GeV]: 5.285
# 68% width [GeV]: 8.891
# Relative MAE  [%]: 9.304
# Relative RMSE [%]: 13.720
